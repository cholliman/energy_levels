# %%
# used to quickly generate energy level daigrams with selectable transitions

# %%
import numpy as _n
import matplotlib.pyplot as plt
from matplotlib.widgets import CheckButtons
# %matplotlib notebook

# %%
states = [[0.2, 0.75, 'S$_{1/2}$'],[7.6, 5.25, 'D$_{3/2}$'],[7.6, 7.75, 'D$_{5/2}$'],
         [1.7, 10.25, 'P$_{1/2}$'],[1.7, 12.75, 'P$_{3/2}$']]

s_and_p_states = [[1.5, 1, 'S$_{1/2}$'],[3, 10.5, 'P$_{1/2}$'],[3, 13, 'P$_{3/2}$']]
d_states = [[5.5, 5.5, 'D$_{3/2}$'],[5.5, 8, 'D$_{5/2}$']]

fig, ax = plt.subplots(figsize=(7, 7))

for i in s_and_p_states:
    ax.hlines(y=i[1], xmin=i[0], xmax=i[0]+2, linewidth=7, color='k')
    ax.text(i[0]-1.3, i[1]-0.25, i[2], fontsize=25, fontweight='bold')

for i in d_states:
    ax.hlines(y=i[1], xmin=i[0], xmax=i[0]+2, linewidth=7, color='k')
    ax.text(i[0]+2.1, i[1]-0.25, i[2], fontsize=25, fontweight='bold')

# 382    
ax.text(1,7, '382nm', color='#67006a', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))    
ax.annotate("", xy=(3.25,13), xytext=(1.6,1), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#67006a'})    
# 468
ax.text(3,11.5/2, '468nm', color='#00a0ff', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))    
ax.annotate("", xy=(3.5,10.5), xytext=(2.2,1), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#00a0ff'})    
# 708
ax.text(6.55,13.5/2, '708nm', color='#f10000', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(4.25,13), xytext=(6.85,5.5), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#f10000'})
# 728
ax.text(3.25,4.75, '728nm', color='#cc0000', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(6.5,8), xytext=(2.8,1), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#cc0000'})
# 802
ax.text(5.85,10.5, '802nm', color='#610000', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(4.75,13), xytext=(6.55,8), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#610000'})
# 828
ax.text(5.1,3.25, '828nm', color='#420700', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(6,5.5), xytext=(3.4,1), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#420700'})
# 1079
ax.text(3.40,7.8, '1079nm', color='#2e0500', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(4.25,10.5), xytext=(6.,5.5), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#2e0500'})


ax.text(7.25,12.6, 'Ra$^{+}$', color='black', fontsize='30', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))

ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.tick_params(direction='out', length=6, width=0, colors='r',
               grid_color='r', grid_alpha=0.5)

plt.xlim(0,9)
plt.ylim(0,14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
states = [[0.2, 0.75, 'S$_{1/2}$'],[7.6, 5.25, 'D$_{3/2}$'],[7.6, 7.75, 'D$_{5/2}$'],
         [1.7, 10.25, 'P$_{1/2}$'],[1.7, 12.75, 'P$_{3/2}$']]

s_and_p_states = [[1.5, 1, 'S$_{1/2}$'],[3, 10.5, 'P$_{1/2}$'],[3, 13, 'P$_{3/2}$']]
d_states = [[5.5, 5.5, 'D$_{3/2}$'],[5.5, 8, 'D$_{5/2}$']]

fig, ax = plt.subplots(figsize=(7, 7))

for i in s_and_p_states:
    ax.hlines(y=i[1], xmin=i[0], xmax=i[0]+2, linewidth=7, color='k')
    ax.text(i[0]-1.3, i[1]-0.25, i[2], fontsize=25, fontweight='bold')

for i in d_states:
    ax.hlines(y=i[1], xmin=i[0], xmax=i[0]+2, linewidth=7, color='k')
    ax.text(i[0]+2.1, i[1]-0.25, i[2], fontsize=25, fontweight='bold')

# 408    
ax.text(1,7, '408nm', color='#8000d3', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))    
ax.annotate("", xy=(3.25,13), xytext=(1.6,1), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#8000d3'})    
# 422
ax.text(3,11.5/2, '422nm', color='#6100ff', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))    
ax.annotate("", xy=(3.5,10.5), xytext=(2.2,1), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#6100ff'})    
# 1004
ax.text(6.55,13.5/2, '1004nm', color='#610000', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(4.25,13), xytext=(6.85,5.5), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#610000'})
# 674
ax.text(3.25,4.75, '674nm', color='#ff0000', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(6.5,8), xytext=(2.8,1), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#ff0000'})
# 1033
ax.text(5.85,10.5, '1033nm', color='#420700', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(4.75,13), xytext=(6.55,8), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#420700'})
# 687
ax.text(5.1,3.25, '687nm', color='#fd0000', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(6,5.5), xytext=(3.4,1), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#fd0000'})
# 1092
ax.text(3.40,7.8, '1092nm', color='#2e0500', fontsize='15', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))
ax.annotate("", xy=(4.25,10.5), xytext=(6.,5.5), arrowprops={'arrowstyle':"<|-|>", 'lw': 4, 'color':'#2e0500'})


ax.text(7.25,12.6, 'Sr$^{+}$', color='black', fontsize='30', fontweight='bold', 
        bbox=dict(facecolor='white', edgecolor='white', pad=0.0))

ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.tick_params(direction='out', length=6, width=0, colors='r',
               grid_color='r', grid_alpha=0.5)

plt.xlim(0,9)
plt.ylim(0,14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
